# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepakraj14-tamil/Projects/blob/main/plant-disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set the path to your training, testing, and validation data directories
train_dir = '/content/drive/MyDrive/archive/Train/Train'
test_dir = '/content/drive/MyDrive/archive/Test/Test'
valid_dir = '/content/drive/MyDrive/archive/Validation/Validation'

# %%
import os
import matplotlib.pyplot as plt

# Get the list of directories in the test data directory
test_folders = os.listdir(test_dir)

# Iterate over each folder
for folder in test_folders:
    folder_path = os.path.join(test_dir, folder)
    if os.path.isdir(folder_path):
        # Get the list of images in the folder
        image_files = os.listdir(folder_path)
        
        # Initialize lists to store the labels and values for each image
        labels = []
        values = []

        # Iterate over each image
        for image_file in image_files:
            # Add the image name as the label and a constant value as the count
            labels.append(image_file)
            values.append(1)

        # Create the bar plot
        plt.figure(figsize=(10, 6))
        plt.bar(labels, values)

        # Add labels and title
        plt.xlabel('Image')
        plt.ylabel('Count')
        plt.title(f'Number of Images in {folder}')

        # Rotate the x-axis labels for better visibility
        plt.xticks(rotation=90)

        # Display the plot
        plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['train', 'test', 'valid']
values = [160, 135, 60]

# Create the bar plot
plt.bar(labels, values)

# Add labels and title
plt.xlabel('Classes')
plt.ylabel('Count')
plt.title('Dataset Distribution')

# Display the plot
plt.show()

# %%
# Define image parameters
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)  # 3 channels for RGB images

# Define the number of classes (plant diseases) in your dataset
num_classes = 3

# Set the batch size and number of epochs
batch_size = 32
epochs = 20

# Data augmentation for the training set
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
# Rescaling for the testing and validation sets
test_datagen = ImageDataGenerator(rescale=1.0 / 255)
valid_datagen = ImageDataGenerator(rescale=1.0 / 255)


# Load and augment the training data
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

# Load the testing data
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Load the validation data
valid_data = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 1299 images belonging to 3 classes.
# Found 150 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
# Build the CNN model with increased complexity
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_9 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 36, 36, 64)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 34, 34, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 17, 17, 128)      0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 15, 15, 256)       295168
#
#  max_pooling2d_12 (MaxPoolin  (None, 7, 7, 256)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 512)         1180160
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
# ...

# %%
# Train the model
history = model.fit(
    train_data,
    steps_per_epoch=train_data.samples // batch_size,
    epochs=epochs,
    validation_data=valid_data,
    validation_steps = valid_data.samples // batch_size
)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 537s 13s/step - loss: 1.0353 - accuracy: 0.4578 - val_loss: 0.8274 - val_accuracy: 0.5938
# Epoch 2/20
# 40/40 [==============================] - 346s 9s/step - loss: 0.7119 - accuracy: 0.6504 - val_loss: 0.6203 - val_accuracy: 0.6562
# Epoch 3/20
# 40/40 [==============================] - 356s 9s/step - loss: 0.6325 - accuracy: 0.7214 - val_loss: 0.5111 - val_accuracy: 0.8125
# Epoch 4/20
# 40/40 [==============================] - 350s 9s/step - loss: 0.6107 - accuracy: 0.7261 - val_loss: 0.4848 - val_accuracy: 0.7812
# Epoch 5/20
# 40/40 [==============================] - 347s 9s/step - loss: 0.4909 - accuracy: 0.7948 - val_loss: 0.4741 - val_accuracy: 0.7812
# Epoch 6/20
# 40/40 [==============================] - 351s 9s/step - loss: 0.4548 - accuracy: 0.7972 - val_loss: 0.4979 - val_accuracy: 0.6875
# Epoch 7/20
# ...

# %%
# Evaluate the model on the testing data
test_loss, test_accuracy = model.evaluate(test_data, verbose=2)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 5/5 - 57s - loss: 0.2030 - accuracy: 0.9467 - 57s/epoch - 11s/step
# Test Loss: 0.2030075639486313
# Test Accuracy: 0.9466666579246521

# %%
# Plot the training and validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import numpy as np
from sklearn.metrics import accuracy_score

y_true = test_data.classes
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# 5/5 [==============================] - 30s 5s/step
# Accuracy: 0.9466666666666667

# %%
import matplotlib.pyplot as plt

# Assuming you have the training and validation accuracy history from model training
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Calculate error rate for training and validation
train_error_rate = [1 - acc for acc in train_accuracy]
val_error_rate = [1 - acc for acc in val_accuracy]

# Plotting
plt.plot(train_error_rate)
plt.plot(val_error_rate)
plt.title('Model Error Rate')
plt.xlabel('Epoch')
plt.ylabel('Error Rate')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a random confusion matrix for illustration
cm = np.random.randint(0, 4, size=(2, 2))

# Define the custom color map
cmap = plt.cm.Blues
cmap.set_under('white')

# Plot the confusion matrix using the custom color map
plt.imshow(cm, cmap=cmap)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[48  2  0]
#  [ 4 46  0]
#  [ 1  1 48]]

# %%
from sklearn.metrics import classification_report

classification_rep = classification_report(y_true, y_pred)
print("Classification Report:")
print(classification_rep)


import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Assuming you have the true labels and predicted labels
# y_true = ...
# y_pred = ...

# Generate the classification report
classification_rep = classification_report(y_true, y_pred, output_dict=True)

# Extract the precision, recall, and F1 score values for each class
precision_values = []
recall_values = []
f1_score_values = []
class_names = []
for class_label, metrics in classification_rep.items():
    if class_label.isdigit():
        class_names.append(class_label)
        precision_values.append(metrics['precision'])
        recall_values.append(metrics['recall'])
        f1_score_values.append(metrics['f1-score'])

# Plot precision, recall, and F1 score values
plt.plot(class_names, precision_values, marker='o', label='Precision')
plt.plot(class_names, recall_values, marker='o', label='Recall')
plt.plot(class_names, f1_score_values, marker='o', label='F1 Score')
plt.title('Performance Metrics for Each Class')
plt.xlabel('Class')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        50
#            1       0.94      0.92      0.93        50
#            2       1.00      0.96      0.98        50
#
#     accuracy                           0.95       150
#    macro avg       0.95      0.95      0.95       150
# weighted avg       0.95      0.95      0.95       150

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarize the true labels
y_true_bin = label_binarize(y_true, classes=np.unique(y_true))

# Calculate the predicted probabilities for all classes
y_scores = model.predict(test_data)

# Calculate the ROC curve and AUC for each class
fpr = dict()
tpr = dict()
auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    auc[i] = roc_auc_score(y_true_bin[:, i], y_scores[:, i])

# Plot ROC curves for each class
plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple']  # Adjust the colors based on the number of classes
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], color=colors[i], label='Class {0} (AUC = {1:.2f})'.format(i, auc[i]))

plt.title('Receiver Operating Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 5/5 [==============================] - 29s 5s/step
